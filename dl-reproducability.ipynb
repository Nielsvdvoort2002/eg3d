# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/3dswap/train_inversion.py
# /kaggle/input/3dswap/README.md
# /kaggle/input/3dswap/run_3dSwap.py
# /kaggle/input/3dswap/requirements.txt
# /kaggle/input/3dswap/run_inversion.py
# /kaggle/input/3dswap/train_faceswap.py
# /kaggle/input/3dswap/.gitattributes
# /kaggle/input/3dswap/options/train_options.py
# /kaggle/input/3dswap/options/__init__.py
# /kaggle/input/3dswap/options/test_options.py
# /kaggle/input/3dswap/utils/legacy.py
# /kaggle/input/3dswap/utils/data_utils.py
# /kaggle/input/3dswap/utils/camera_utils.py
# /kaggle/input/3dswap/utils/shape_utils.py
# /kaggle/input/3dswap/configs/data_configs.py
# /kaggle/input/3dswap/configs/paths_config.py
# /kaggle/input/3dswap/configs/hyperparameters.py
# /kaggle/input/3dswap/configs/transforms_config.py
# /kaggle/input/3dswap/configs/__init__.py
# /kaggle/input/3dswap/configs/evaluation_config.py
# /kaggle/input/3dswap/configs/global_config.py
# /kaggle/input/3dswap/eg3d/.gitignore
# /kaggle/input/3dswap/eg3d/.gitmodules
# ...

# %%
# !pip install mrcfile
# !git clone https://github.com/Nielsvdvoort2002/eg3d.git
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 677.4 kB/s eta 0:00:00
# ...
# Cloning into 'eg3d'...
# remote: Enumerating objects: 194, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 194 (delta 52), reused 41 (delta 38), pack-reused 89
# Receiving objects: 100% (194/194), 2.10 MiB | 14.74 MiB/s, done.
# Resolving deltas: 100% (69/69), done.

# %%
# !python eg3d/eg3d/gen_samples.py --outdir=out --shapes=true --trunc=0.7 --seeds=0-3 --network=../../kaggle/input/3dswap/checkpoints/ffhq512-128.pkl
# !python eg3d/eg3d/gen_samples.py --outdir=out --trunc=0.7 --seeds=100-1000 --network=../../kaggle/input/3dswap/checkpoints/ffhq512-128.pkl
# Out:
# Loading networks from "../../kaggle/input/3dswap/checkpoints/ffhq512-128.pkl"...
# Generating image for seed 100 (0/901) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 101 (1/901) ...
# Generating image for seed 102 (2/901) ...
# Generating image for seed 103 (3/901) ...
# Generating image for seed 104 (4/901) ...
# Generating image for seed 105 (5/901) ...
# Generating image for seed 106 (6/901) ...
# Generating image for seed 107 (7/901) ...
# Generating image for seed 108 (8/901) ...
# Generating image for seed 109 (9/901) ...
# Generating image for seed 110 (10/901) ...
# Generating image for seed 111 (11/901) ...
# Generating image for seed 112 (12/901) ...
# Generating image for seed 113 (13/901) ...
# Generating image for seed 114 (14/901) ...
# Generating image for seed 115 (15/901) ...
# Generating image for seed 116 (16/901) ...
# Generating image for seed 117 (17/901) ...
# ...

# %%
# !ls /kaggle/working/out
from IPython.display import Image
Image(filename='/kaggle/working/out/seed0100.png')

# %%
import shutil
shutil.make_archive("output", 'zip', "/kaggle/working/out")
# Out:
# '/kaggle/working/output.zip'
